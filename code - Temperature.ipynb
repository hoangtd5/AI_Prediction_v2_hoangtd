# %% [markdown]
# ## Power generation Forecasting
# by Hoang cute

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import warnings
warnings.simplefilter(action='ignore', category=(FutureWarning, UserWarning))
# Out:
# 2022-11-30 11:39:37.952007: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-30 11:39:37.957780: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-30 11:39:37.957814: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# 2022-11-30 11:39:40.036604: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-30 11:39:40.042860: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-30 11:39:40.043125: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-30 11:39:40.043157: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (forecast): /proc/driver/nvidia/version does not exist

# %%
# Read the datasets
import glob
path = r'/home/wicomai/Downloads/AI_ver_02/weather-283' # use your path
all_files = glob.glob(path + "/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0,encoding = 'unicode_escape')
    df = df.rename(columns={'ÁöÁ¡':'Point','ÀÏ½Ã':'datetime','±â¿Â(¡ÆC)':'Temperature (°C)','´©Àû°­¼ö·®(mm)':'Precipitation (mm)','Ç³Çâ(deg)':'Wind Direction (deg)'
    ,'Ç³¼Ó(m/s)':'Wind Speed ​​(m/s)','ÇöÁö±â¾Ð(hPa)':'Barometric Pressure (hPa)','ÇØ¸é±â¾Ð(hPa)':'Sea Level Pressure (hPa)','½Àµµ(%)':'Humidity (%)',
    'ÀÏ»ç(MJ/m2)':'Insolation (MJ/m^2)','ÀÏÁ¶(hr)':'Sunlight (hr)'})
    df['datetime'] = pd.to_datetime(df['datetime'])
    li.append(df)

df_weather = pd.concat(li, axis=0, ignore_index=True)
df_weather = df_weather.drop_duplicates(keep=False)
df_weather = df_weather.drop(['Point'],axis=1).set_index('datetime')
df_weather.head()
# Out:
#                      Temperature (°C)  °­¼ö·®(mm)  Wind Speed ​​(m/s)  \
# datetime
# 2021-01-01 00:00:00              -4.2         NaN                 4.1
# 2021-01-01 01:00:00              -4.5         NaN                 4.8
# 2021-01-01 02:00:00              -5.2         NaN                 3.0
# 2021-01-01 03:00:00              -5.2         NaN                 4.3
# 2021-01-01 04:00:00              -4.9         NaN                 3.9
#
#                      Ç³Çâ(16¹æÀ§)  Humidity (%)  Áõ±â¾Ð(hPa)  ÀÌ½½Á¡¿Âµµ(¡ÆC)  \
# datetime
# 2021-01-01 00:00:00         320.0          60.0          2.7            -10.8
# 2021-01-01 01:00:00         320.0          56.0          2.5            -11.9
# 2021-01-01 02:00:00         340.0          60.0          2.5            -11.7
# 2021-01-01 03:00:00         340.0          60.0          2.5            -11.7
# 2021-01-01 04:00:00         340.0          60.0          2.6            -11.4
#
#                      Barometric Pressure (hPa)  Sea Level Pressure (hPa)  \
# datetime
# 2021-01-01 00:00:00                     1020.5                    1025.7
# 2021-01-01 01:00:00                     1020.9                    1026.1
# 2021-01-01 02:00:00                     1020.8                    1026.0
# 2021-01-01 03:00:00                     1021.1                    1026.3
# 2021-01-01 04:00:00                     1021.5                    1026.7
#
#                      Sunlight (hr)  ...  ¿îÇü(¿îÇü¾à¾î)  ÃÖÀú¿î°í(100m )  \
# datetime                            ...
# 2021-01-01 00:00:00            NaN  ...             NaN              NaN
# 2021-01-01 01:00:00            NaN  ...             NaN              NaN
# 2021-01-01 02:00:00            NaN  ...             NaN              NaN
# 2021-01-01 03:00:00            NaN  ...             NaN              NaN
# 2021-01-01 04:00:00            NaN  ...             NaN              NaN
#
#                      ½ÃÁ¤(10m)  Áö¸é»óÅÂ(Áö¸é»óÅÂÄÚµå)  Çö»ó¹øÈ£(±¹³»½Ä)  \
# datetime
# 2021-01-01 00:00:00     3119.0                     NaN               NaN
# 2021-01-01 01:00:00     3053.0                     NaN               NaN
# 2021-01-01 02:00:00     3116.0                     NaN               NaN
# 2021-01-01 03:00:00     3068.0                     NaN               NaN
# 2021-01-01 04:00:00     3120.0                     NaN               NaN
#
#                      Áö¸é¿Âµµ(¡ÆC)  5cm ÁöÁß¿Âµµ(¡ÆC)  10cm ÁöÁß¿Âµµ(¡ÆC)  \
# datetime
# 2021-01-01 00:00:00           -5.1               -1.6                -0.8
# 2021-01-01 01:00:00           -5.6               -1.9                -1.0
# 2021-01-01 02:00:00           -6.3               -2.2                -1.2
# 2021-01-01 03:00:00           -6.5               -2.5                -1.3
# 2021-01-01 04:00:00           -6.6               -2.7                -1.4
#
#                      20cm ÁöÁß¿Âµµ(¡ÆC)  30cm ÁöÁß¿Âµµ(¡ÆC)
# datetime
# 2021-01-01 00:00:00                 1.0                 2.7
# 2021-01-01 01:00:00                 1.0                 2.7
# 2021-01-01 02:00:00                 1.0                 2.7
# 2021-01-01 03:00:00                 0.9                 2.7
# 2021-01-01 04:00:00                 0.9                 2.6
#
# [5 rows x 25 columns]

# %%
print(len(df_weather))
# Out:
# 43807

# %%
df_weather.head()
# Out:
#                      Temperature (°C)  °­¼ö·®(mm)  Wind Speed ​​(m/s)  \
# datetime
# 2021-01-01 00:00:00              -4.2         NaN                 4.1
# 2021-01-01 01:00:00              -4.5         NaN                 4.8
# 2021-01-01 02:00:00              -5.2         NaN                 3.0
# 2021-01-01 03:00:00              -5.2         NaN                 4.3
# 2021-01-01 04:00:00              -4.9         NaN                 3.9
#
#                      Ç³Çâ(16¹æÀ§)  Humidity (%)  Áõ±â¾Ð(hPa)  ÀÌ½½Á¡¿Âµµ(¡ÆC)  \
# datetime
# 2021-01-01 00:00:00         320.0          60.0          2.7            -10.8
# 2021-01-01 01:00:00         320.0          56.0          2.5            -11.9
# 2021-01-01 02:00:00         340.0          60.0          2.5            -11.7
# 2021-01-01 03:00:00         340.0          60.0          2.5            -11.7
# 2021-01-01 04:00:00         340.0          60.0          2.6            -11.4
#
#                      Barometric Pressure (hPa)  Sea Level Pressure (hPa)  \
# datetime
# 2021-01-01 00:00:00                     1020.5                    1025.7
# 2021-01-01 01:00:00                     1020.9                    1026.1
# 2021-01-01 02:00:00                     1020.8                    1026.0
# 2021-01-01 03:00:00                     1021.1                    1026.3
# 2021-01-01 04:00:00                     1021.5                    1026.7
#
#                      Sunlight (hr)  ...  ¿îÇü(¿îÇü¾à¾î)  ÃÖÀú¿î°í(100m )  \
# datetime                            ...
# 2021-01-01 00:00:00            NaN  ...             NaN              NaN
# 2021-01-01 01:00:00            NaN  ...             NaN              NaN
# 2021-01-01 02:00:00            NaN  ...             NaN              NaN
# 2021-01-01 03:00:00            NaN  ...             NaN              NaN
# 2021-01-01 04:00:00            NaN  ...             NaN              NaN
#
#                      ½ÃÁ¤(10m)  Áö¸é»óÅÂ(Áö¸é»óÅÂÄÚµå)  Çö»ó¹øÈ£(±¹³»½Ä)  \
# datetime
# 2021-01-01 00:00:00     3119.0                     NaN               NaN
# 2021-01-01 01:00:00     3053.0                     NaN               NaN
# 2021-01-01 02:00:00     3116.0                     NaN               NaN
# 2021-01-01 03:00:00     3068.0                     NaN               NaN
# 2021-01-01 04:00:00     3120.0                     NaN               NaN
#
#                      Áö¸é¿Âµµ(¡ÆC)  5cm ÁöÁß¿Âµµ(¡ÆC)  10cm ÁöÁß¿Âµµ(¡ÆC)  \
# datetime
# 2021-01-01 00:00:00           -5.1               -1.6                -0.8
# 2021-01-01 01:00:00           -5.6               -1.9                -1.0
# 2021-01-01 02:00:00           -6.3               -2.2                -1.2
# 2021-01-01 03:00:00           -6.5               -2.5                -1.3
# 2021-01-01 04:00:00           -6.6               -2.7                -1.4
#
#                      20cm ÁöÁß¿Âµµ(¡ÆC)  30cm ÁöÁß¿Âµµ(¡ÆC)
# datetime
# 2021-01-01 00:00:00                 1.0                 2.7
# 2021-01-01 01:00:00                 1.0                 2.7
# 2021-01-01 02:00:00                 1.0                 2.7
# 2021-01-01 03:00:00                 0.9                 2.7
# 2021-01-01 04:00:00                 0.9                 2.6
#
# [5 rows x 25 columns]

# %%
df_weather.to_csv('Gyeongjusi_hourly.csv')

# %%
def df_convert_dtypes(df, convert_from, convert_to):
    cols = df.select_dtypes(include=[convert_from]).columns
    for col in cols:
        df[col] = df[col].values.astype(convert_to)
    return df

# %%
df_final = df_convert_dtypes(df_weather, np.object, np.float64)
df_final.head(30)
# Out:
# /tmp/ipykernel_47577/669393798.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_final = df_convert_dtypes(df_weather, np.object, np.float64)
#                      Temperature (°C)  °­¼ö·®(mm)  Wind Speed ​​(m/s)  \
# datetime
# 2021-01-01 00:00:00              -4.2         NaN                 4.1
# 2021-01-01 01:00:00              -4.5         NaN                 4.8
# 2021-01-01 02:00:00              -5.2         NaN                 3.0
# 2021-01-01 03:00:00              -5.2         NaN                 4.3
# 2021-01-01 04:00:00              -4.9         NaN                 3.9
# 2021-01-01 05:00:00              -4.9         NaN                 5.2
# 2021-01-01 06:00:00              -4.8         NaN                 5.2
# 2021-01-01 07:00:00              -8.1         NaN                 2.6
# 2021-01-01 08:00:00              -9.0         NaN                 2.5
# 2021-01-01 09:00:00              -5.9         NaN                 2.5
# 2021-01-01 10:00:00              -2.8         NaN                 0.7
# 2021-01-01 11:00:00              -0.6         NaN                 1.0
# 2021-01-01 12:00:00               0.2         NaN                 1.2
# 2021-01-01 13:00:00               1.6         NaN                 3.1
# 2021-01-01 14:00:00               2.0         NaN                 3.8
# 2021-01-01 15:00:00               2.8         NaN                 4.6
# 2021-01-01 16:00:00               2.6         NaN                 1.2
# 2021-01-01 17:00:00               1.9         NaN                 1.6
# 2021-01-01 18:00:00               1.1         NaN                 0.9
# 2021-01-01 19:00:00              -0.9         NaN                 1.3
# 2021-01-01 20:00:00              -1.5         NaN                 0.4
# 2021-01-01 21:00:00              -1.9         NaN                 0.9
# 2021-01-01 22:00:00              -2.7         NaN                 1.3
# 2021-01-01 23:00:00              -4.0         NaN                 0.8
# 2021-01-02 00:00:00              -5.0         NaN                 1.5
# 2021-01-02 01:00:00              -6.5         NaN                 1.0
# 2021-01-02 02:00:00              -6.0         NaN                 1.4
# 2021-01-02 03:00:00              -5.0         NaN                 2.6
# 2021-01-02 04:00:00              -4.8         NaN                 2.9
# 2021-01-02 05:00:00              -5.3         NaN                 3.2
#
#                      Ç³Çâ(16¹æÀ§)  Humidity (%)  Áõ±â¾Ð(hPa)  ÀÌ½½Á¡¿Âµµ(¡ÆC)  \
# datetime
# 2021-01-01 00:00:00         320.0          60.0          2.7            -10.8
# 2021-01-01 01:00:00         320.0          56.0          2.5            -11.9
# 2021-01-01 02:00:00         340.0          60.0          2.5            -11.7
# 2021-01-01 03:00:00         340.0          60.0          2.5            -11.7
# 2021-01-01 04:00:00         340.0          60.0          2.6            -11.4
# 2021-01-01 05:00:00         340.0          59.0          2.5            -11.6
# 2021-01-01 06:00:00         340.0          55.0          2.4            -12.4
# 2021-01-01 07:00:00         180.0          74.0          2.5            -11.9
# 2021-01-01 08:00:00         180.0          80.0          2.5            -11.8
# 2021-01-01 09:00:00         200.0          67.0          2.6            -11.0
# 2021-01-01 10:00:00         110.0          55.0          2.7            -10.6
# 2021-01-01 11:00:00         230.0          46.0          2.7            -10.8
# 2021-01-01 12:00:00         340.0          45.0          2.8            -10.3
# 2021-01-01 13:00:00         270.0          43.0          3.0             -9.6
# 2021-01-01 14:00:00         270.0          44.0          3.1             -9.0
# 2021-01-01 15:00:00         250.0          44.0          3.3             -8.2
# 2021-01-01 16:00:00         250.0          44.0          3.2             -8.4
# 2021-01-01 17:00:00         270.0          49.0          3.4             -7.7
# 2021-01-01 18:00:00         270.0          53.0          3.5             -7.4
# 2021-01-01 19:00:00         180.0          65.0          3.7             -6.6
# 2021-01-01 20:00:00           0.0          66.0          3.6             -7.0
# 2021-01-01 21:00:00         200.0          75.0          4.0             -5.7
# 2021-01-01 22:00:00         160.0          73.0          3.7             -6.8
# 2021-01-01 23:00:00         250.0          84.0          3.8             -6.3
# 2021-01-02 00:00:00         180.0          84.0          3.6             -7.2
# 2021-01-02 01:00:00         250.0          86.0          3.2             -8.4
# 2021-01-02 02:00:00         180.0          88.0          3.5             -7.6
# 2021-01-02 03:00:00         180.0          82.0          3.5             -7.6
# 2021-01-02 04:00:00         180.0          82.0          3.5             -7.4
# 2021-01-02 05:00:00         180.0          83.0          3.4             -7.7
#
#                      Barometric Pressure (hPa)  Sea Level Pressure (hPa)  \
# datetime
# 2021-01-01 00:00:00                     1020.5                    1025.7
# 2021-01-01 01:00:00                     1020.9                    1026.1
# 2021-01-01 02:00:00                     1020.8                    1026.0
# 2021-01-01 03:00:00                     1021.1                    1026.3
# 2021-01-01 04:00:00                     1021.5                    1026.7
# 2021-01-01 05:00:00                     1021.3                    1026.5
# 2021-01-01 06:00:00                     1021.7                    1026.9
# 2021-01-01 07:00:00                     1021.9                    1027.2
# 2021-01-01 08:00:00                     1022.4                    1027.7
# 2021-01-01 09:00:00                     1023.1                    1028.3
# 2021-01-01 10:00:00                     1022.6                    1027.8
# 2021-01-01 11:00:00                     1022.2                    1027.3
# 2021-01-01 12:00:00                     1020.9                    1026.0
# 2021-01-01 13:00:00                     1019.6                    1024.7
# 2021-01-01 14:00:00                     1019.0                    1024.1
# 2021-01-01 15:00:00                     1018.9                    1023.9
# 2021-01-01 16:00:00                     1018.8                    1023.9
# 2021-01-01 17:00:00                     1018.9                    1024.0
# 2021-01-01 18:00:00                     1019.0                    1024.1
# 2021-01-01 19:00:00                     1019.3                    1024.4
# 2021-01-01 20:00:00                     1019.6                    1024.7
# 2021-01-01 21:00:00                     1019.7                    1024.8
# 2021-01-01 22:00:00                     1019.5                    1024.7
# 2021-01-01 23:00:00                     1019.6                    1024.8
# 2021-01-02 00:00:00                     1019.5                    1024.7
# 2021-01-02 01:00:00                     1019.7                    1024.9
# 2021-01-02 02:00:00                     1020.0                    1025.2
# 2021-01-02 03:00:00                     1020.2                    1025.4
# 2021-01-02 04:00:00                     1020.3                    1025.5
# 2021-01-02 05:00:00                     1020.2                    1025.4
#
#                      Sunlight (hr)  ...  ¿îÇü(¿îÇü¾à¾î)  ÃÖÀú¿î°í(100m )  \
# datetime                            ...
# 2021-01-01 00:00:00            NaN  ...             NaN              NaN
# 2021-01-01 01:00:00            NaN  ...             NaN              NaN
# 2021-01-01 02:00:00            NaN  ...             NaN              NaN
# 2021-01-01 03:00:00            NaN  ...             NaN              NaN
# 2021-01-01 04:00:00            NaN  ...             NaN              NaN
# 2021-01-01 05:00:00            NaN  ...             NaN              NaN
# 2021-01-01 06:00:00            NaN  ...             NaN              NaN
# 2021-01-01 07:00:00            NaN  ...             NaN              NaN
# 2021-01-01 08:00:00            0.0  ...             NaN              NaN
# 2021-01-01 09:00:00            0.7  ...             NaN              NaN
# 2021-01-01 10:00:00            0.8  ...             NaN              4.0
# 2021-01-01 11:00:00            0.4  ...             NaN              3.0
# 2021-01-01 12:00:00            0.3  ...             NaN              3.0
# 2021-01-01 13:00:00            0.4  ...             NaN              4.0
# 2021-01-01 14:00:00            0.5  ...             NaN              4.0
# 2021-01-01 15:00:00            0.3  ...             NaN              4.0
# 2021-01-01 16:00:00            0.5  ...             NaN              4.0
# 2021-01-01 17:00:00            0.1  ...             NaN              4.0
# 2021-01-01 18:00:00            0.0  ...             NaN              4.0
# 2021-01-01 19:00:00            NaN  ...             NaN              4.0
# 2021-01-01 20:00:00            NaN  ...             NaN              4.0
# 2021-01-01 21:00:00            NaN  ...             NaN              5.0
# 2021-01-01 22:00:00            NaN  ...             NaN              5.0
# 2021-01-01 23:00:00            NaN  ...             NaN              4.0
# 2021-01-02 00:00:00            NaN  ...             NaN              NaN
# 2021-01-02 01:00:00            NaN  ...             NaN              NaN
# 2021-01-02 02:00:00            NaN  ...             NaN              NaN
# 2021-01-02 03:00:00            NaN  ...             NaN              2.0
# 2021-01-02 04:00:00            NaN  ...             NaN              3.0
# 2021-01-02 05:00:00            NaN  ...             NaN              NaN
#
#                      ½ÃÁ¤(10m)  Áö¸é»óÅÂ(Áö¸é»óÅÂÄÚµå)  Çö»ó¹øÈ£(±¹³»½Ä)  \
# datetime
# 2021-01-01 00:00:00     3119.0                     NaN               NaN
# 2021-01-01 01:00:00     3053.0                     NaN               NaN
# 2021-01-01 02:00:00     3116.0                     NaN               NaN
# 2021-01-01 03:00:00     3068.0                     NaN               NaN
# 2021-01-01 04:00:00     3120.0                     NaN               NaN
# 2021-01-01 05:00:00     3238.0                     NaN               NaN
# 2021-01-01 06:00:00     3282.0                     NaN               NaN
# 2021-01-01 07:00:00     2327.0                     NaN               NaN
# 2021-01-01 08:00:00     2022.0                     NaN               NaN
# 2021-01-01 09:00:00     2342.0                     NaN               NaN
# 2021-01-01 10:00:00     2940.0                     NaN               NaN
# 2021-01-01 11:00:00     3309.0                     NaN               NaN
# 2021-01-01 12:00:00     3749.0                     NaN               NaN
# 2021-01-01 13:00:00     4280.0                     NaN               NaN
# 2021-01-01 14:00:00     4366.0                     NaN               NaN
# 2021-01-01 15:00:00     4163.0                     NaN               NaN
# 2021-01-01 16:00:00     3883.0                     NaN               NaN
# 2021-01-01 17:00:00     3904.0                     NaN               NaN
# 2021-01-01 18:00:00     3274.0                     NaN               NaN
# 2021-01-01 19:00:00     2119.0                     NaN               NaN
# 2021-01-01 20:00:00     2426.0                     NaN               NaN
# 2021-01-01 21:00:00     2291.0                     NaN               NaN
# 2021-01-01 22:00:00     1968.0                     NaN               NaN
# 2021-01-01 23:00:00     1281.0                     NaN               NaN
# 2021-01-02 00:00:00     1420.0                     NaN               NaN
# 2021-01-02 01:00:00     1132.0                     NaN               NaN
# 2021-01-02 02:00:00     1084.0                     NaN               NaN
# 2021-01-02 03:00:00     1201.0                     NaN               NaN
# 2021-01-02 04:00:00     1213.0                     NaN               NaN
# 2021-01-02 05:00:00     1404.0                     NaN               NaN
#
#                      Áö¸é¿Âµµ(¡ÆC)  5cm ÁöÁß¿Âµµ(¡ÆC)  10cm ÁöÁß¿Âµµ(¡ÆC)  \
# datetime
# 2021-01-01 00:00:00           -5.1               -1.6                -0.8
# 2021-01-01 01:00:00           -5.6               -1.9                -1.0
# 2021-01-01 02:00:00           -6.3               -2.2                -1.2
# 2021-01-01 03:00:00           -6.5               -2.5                -1.3
# 2021-01-01 04:00:00           -6.6               -2.7                -1.4
# 2021-01-01 05:00:00           -6.5               -2.9                -1.5
# 2021-01-01 06:00:00           -6.5               -2.9                -1.6
# 2021-01-01 07:00:00           -7.7               -3.2                -1.7
# 2021-01-01 08:00:00           -8.0               -3.6                -2.0
# 2021-01-01 09:00:00           -5.1               -3.2                -1.9
# 2021-01-01 10:00:00           -1.4               -1.9                -1.4
# 2021-01-01 11:00:00            1.2               -1.1                -0.9
# 2021-01-01 12:00:00            3.7               -0.6                -0.7
# 2021-01-01 13:00:00            4.4               -0.3                -0.5
# 2021-01-01 14:00:00            4.3                0.2                -0.3
# 2021-01-01 15:00:00            3.8                0.3                -0.2
# 2021-01-01 16:00:00            2.8                0.7                -0.2
# 2021-01-01 17:00:00            0.4                0.4                -0.2
# 2021-01-01 18:00:00           -1.2               -0.1                -0.3
# 2021-01-01 19:00:00           -1.4               -0.4                -0.3
# 2021-01-01 20:00:00           -1.5               -0.5                -0.4
# 2021-01-01 21:00:00           -2.2               -0.5                -0.4
# 2021-01-01 22:00:00           -2.6               -0.5                -0.4
# 2021-01-01 23:00:00           -3.4               -0.6                -0.5
# 2021-01-02 00:00:00           -4.2               -0.8                -0.5
# 2021-01-02 01:00:00           -5.0               -0.9                -0.6
# 2021-01-02 02:00:00           -4.2               -1.1                -0.6
# 2021-01-02 03:00:00           -3.3               -1.2                -0.6
# 2021-01-02 04:00:00           -3.4               -1.2                -0.6
# 2021-01-02 05:00:00           -4.8               -1.4                -0.7
#
#                      20cm ÁöÁß¿Âµµ(¡ÆC)  30cm ÁöÁß¿Âµµ(¡ÆC)
# datetime
# 2021-01-01 00:00:00                 1.0                 2.7
# 2021-01-01 01:00:00                 1.0                 2.7
# 2021-01-01 02:00:00                 1.0                 2.7
# 2021-01-01 03:00:00                 0.9                 2.7
# 2021-01-01 04:00:00                 0.9                 2.6
# 2021-01-01 05:00:00                 0.9                 2.6
# 2021-01-01 06:00:00                 0.8                 2.6
# 2021-01-01 07:00:00                 0.7                 2.5
# 2021-01-01 08:00:00                 0.6                 2.5
# 2021-01-01 09:00:00                 0.7                 2.5
# 2021-01-01 10:00:00                 0.7                 2.6
# 2021-01-01 11:00:00                 0.7                 2.5
# 2021-01-01 12:00:00                 0.7                 2.5
# 2021-01-01 13:00:00                 0.7                 2.4
# 2021-01-01 14:00:00                 0.7                 2.4
# 2021-01-01 15:00:00                 0.7                 2.4
# 2021-01-01 16:00:00                 0.8                 2.4
# 2021-01-01 17:00:00                 0.7                 2.4
# 2021-01-01 18:00:00                 0.7                 2.3
# 2021-01-01 19:00:00                 0.7                 2.3
# 2021-01-01 20:00:00                 0.7                 2.3
# 2021-01-01 21:00:00                 0.7                 2.3
# 2021-01-01 22:00:00                 0.7                 2.3
# 2021-01-01 23:00:00                 0.7                 2.3
# 2021-01-02 00:00:00                 0.8                 2.3
# 2021-01-02 01:00:00                 0.8                 2.3
# 2021-01-02 02:00:00                 0.8                 2.3
# 2021-01-02 03:00:00                 0.9                 2.3
# 2021-01-02 04:00:00                 0.9                 2.3
# 2021-01-02 05:00:00                 0.9                 2.3
#
# [30 rows x 25 columns]

# %%
print(len(df_final))
# Out:
# 43807

# %%
df_final.describe()
# Out:
#        Temperature (°C)   °­¼ö·®(mm)  Wind Speed ​​(m/s)  Ç³Çâ(16¹æÀ§)  \
# count      43785.000000  3635.000000        43753.000000  43753.000000
# mean          13.824908     1.545557            2.457985    200.334606
# std           10.039401     3.148289            1.675635    106.029518
# min          -12.900000     0.000000            0.000000      0.000000
# 25%            5.700000     0.000000            1.200000    140.000000
# 50%           14.600000     0.500000            2.000000    200.000000
# 75%           21.900000     1.500000            3.400000    290.000000
# max           39.200000    35.500000           15.300000    360.000000
#
#        Humidity (%)   Áõ±â¾Ð(hPa)  ÀÌ½½Á¡¿Âµµ(¡ÆC)  Barometric Pressure (hPa)  \
# count  43792.000000  43791.000000     43789.000000               43748.000000
# mean      68.033947     12.939561         7.058423                1011.761377
# std       23.426479      8.807872        11.867791                   7.748347
# min        6.000000      0.500000       -30.800000                 958.800000
# 25%       50.000000      5.400000        -1.600000                1005.900000
# 50%       72.000000     10.400000         7.600000                1011.800000
# 75%       90.000000     19.900000        17.400000                1017.700000
# max      100.000000     37.800000        28.000000                1032.900000
#
#        Sea Level Pressure (hPa)  Sunlight (hr)  ...  ¿îÇü(¿îÇü¾à¾î)  \
# count              43749.000000   23949.000000  ...             0.0
# mean                1016.425713       0.490551  ...             NaN
# std                    7.909147       0.447004  ...             NaN
# min                  963.200000       0.000000  ...             NaN
# 25%                 1010.300000       0.000000  ...             NaN
# 50%                 1016.500000       0.500000  ...             NaN
# 75%                 1022.500000       1.000000  ...             NaN
# max                 1037.800000       1.000000  ...             NaN
#
#        ÃÖÀú¿î°í(100m )     ½ÃÁ¤(10m)  Áö¸é»óÅÂ(Áö¸é»óÅÂÄÚµå)  \
# count     12368.000000  43316.000000                     0.0
# mean          8.996928   1869.025972                     NaN
# std          10.788565   1128.124171                     NaN
# min           1.000000      1.000000                     NaN
# 25%           3.000000    964.000000                     NaN
# 50%           4.000000   1739.000000                     NaN
# 75%          12.000000   2633.000000                     NaN
# max          74.000000   5553.000000                     NaN
#
#        Çö»ó¹øÈ£(±¹³»½Ä)  Áö¸é¿Âµµ(¡ÆC)  5cm ÁöÁß¿Âµµ(¡ÆC)  10cm ÁöÁß¿Âµµ(¡ÆC)  \
# count               0.0   43795.000000       43614.000000        43612.000000
# mean                NaN      15.524825          15.463716           15.519683
# std                 NaN      12.285335          10.525646           10.049339
# min                 NaN     -12.600000          -7.200000           -5.200000
# 25%                 NaN       5.200000           6.200000            6.500000
# 50%                 NaN      15.900000          15.900000           15.900000
# 75%                 NaN      24.200000          23.900000           23.900000
# max                 NaN      59.700000          45.400000           41.300000
#
#        20cm ÁöÁß¿Âµµ(¡ÆC)  30cm ÁöÁß¿Âµµ(¡ÆC)
# count        43573.000000        43609.000000
# mean            15.725250           15.634098
# std              9.436186            8.750255
# min             -1.700000            0.100000
# 25%              7.100000            7.500000
# 50%             16.000000           15.900000
# 75%             24.000000           23.600000
# max             37.700000           33.700000
#
# [8 rows x 25 columns]

# %%
# Display the rows with null values

df_final[df_final.isnull().any(axis=1)].tail()
# Out:
#                      Temperature (°C)  °­¼ö·®(mm)  Wind Speed ​​(m/s)  \
# datetime
# 2019-12-31 19:00:00              -2.0         NaN                 4.2
# 2019-12-31 20:00:00              -2.5         NaN                 1.8
# 2019-12-31 21:00:00              -2.7         NaN                 4.2
# 2019-12-31 22:00:00              -3.2         NaN                 4.2
# 2019-12-31 23:00:00              -3.2         NaN                 4.1
#
#                      Ç³Çâ(16¹æÀ§)  Humidity (%)  Áõ±â¾Ð(hPa)  ÀÌ½½Á¡¿Âµµ(¡ÆC)  \
# datetime
# 2019-12-31 19:00:00         320.0          31.0          1.6            -16.9
# 2019-12-31 20:00:00         340.0          31.0          1.6            -17.3
# 2019-12-31 21:00:00         290.0          30.0          1.5            -17.9
# 2019-12-31 22:00:00         290.0          33.0          1.6            -17.2
# 2019-12-31 23:00:00         320.0          30.0          1.5            -18.3
#
#                      Barometric Pressure (hPa)  Sea Level Pressure (hPa)  \
# datetime
# 2019-12-31 19:00:00                     1026.9                    1032.1
# 2019-12-31 20:00:00                     1026.9                    1032.1
# 2019-12-31 21:00:00                     1026.6                    1031.8
# 2019-12-31 22:00:00                     1026.5                    1031.7
# 2019-12-31 23:00:00                     1026.7                    1031.9
#
#                      Sunlight (hr)  ...  ¿îÇü(¿îÇü¾à¾î)  ÃÖÀú¿î°í(100m )  \
# datetime                            ...
# 2019-12-31 19:00:00            NaN  ...             NaN              NaN
# 2019-12-31 20:00:00            NaN  ...             NaN              NaN
# 2019-12-31 21:00:00            NaN  ...             NaN              NaN
# 2019-12-31 22:00:00            NaN  ...             NaN              NaN
# 2019-12-31 23:00:00            NaN  ...             NaN              NaN
#
#                      ½ÃÁ¤(10m)  Áö¸é»óÅÂ(Áö¸é»óÅÂÄÚµå)  Çö»ó¹øÈ£(±¹³»½Ä)  \
# datetime
# 2019-12-31 19:00:00     3398.0                     NaN               NaN
# 2019-12-31 20:00:00     3150.0                     NaN               NaN
# 2019-12-31 21:00:00     3126.0                     NaN               NaN
# 2019-12-31 22:00:00     3227.0                     NaN               NaN
# 2019-12-31 23:00:00     3290.0                     NaN               NaN
#
#                      Áö¸é¿Âµµ(¡ÆC)  5cm ÁöÁß¿Âµµ(¡ÆC)  10cm ÁöÁß¿Âµµ(¡ÆC)  \
# datetime
# 2019-12-31 19:00:00           -2.6                1.2                 2.2
# 2019-12-31 20:00:00           -3.2                1.0                 2.0
# 2019-12-31 21:00:00           -3.3                0.9                 1.9
# 2019-12-31 22:00:00           -3.6                0.7                 1.7
# 2019-12-31 23:00:00           -3.8                0.6                 1.6
#
#                      20cm ÁöÁß¿Âµµ(¡ÆC)  30cm ÁöÁß¿Âµµ(¡ÆC)
# datetime
# 2019-12-31 19:00:00                 3.6                 5.1
# 2019-12-31 20:00:00                 3.5                 5.0
# 2019-12-31 21:00:00                 3.5                 5.1
# 2019-12-31 22:00:00                 3.3                 5.0
# 2019-12-31 23:00:00                 3.3                 5.0
#
# [5 rows x 25 columns]

# %%
# Fill null values using interpolation

df_final.interpolate(method='linear', limit_direction='forward', inplace=True, axis=0)

# %%
# Display the number of non-zero values in each column

print('Non-zero values in each column:\n', df_final.astype(bool).sum(axis=0), sep='\n')
# Out:
# Non-zero values in each column:
#
# Temperature (°C)             43706
# °­¼ö·®(mm)                   28748
# Wind Speed ​​(m/s)           43602
# Ç³Çâ(16¹æÀ§)                 41576
# Humidity (%)                 43807
# Áõ±â¾Ð(hPa)                  43807
# ÀÌ½½Á¡¿Âµµ(¡ÆC)              43582
# Barometric Pressure (hPa)    43807
# Sea Level Pressure (hPa)     43807
# Sunlight (hr)                20130
# Insolation (MJ/m^2)          41162
# Àû¼³(cm)                     43807
# 3½Ã°£½ÅÀû¼³(cm)              43807
# Àü¿î·®(10ºÐÀ§)               26861
# ÁßÇÏÃþ¿î·®(10ºÐÀ§)           19481
# ¿îÇü(¿îÇü¾à¾î)               43807
# ÃÖÀú¿î°í(100m )              43807
# ½ÃÁ¤(10m)                    43807
# Áö¸é»óÅÂ(Áö¸é»óÅÂÄÚµå)       43807
# Çö»ó¹øÈ£(±¹³»½Ä)             43807
# Áö¸é¿Âµµ(¡ÆC)                43589
# 5cm ÁöÁß¿Âµµ(¡ÆC)            43626
# 10cm ÁöÁß¿Âµµ(¡ÆC)           43568
# 20cm ÁöÁß¿Âµµ(¡ÆC)           43766
# 30cm ÁöÁß¿Âµµ(¡ÆC)           43807
# dtype: int64

# %%
# Check for outliers in 'pressure' column

sns.boxplot(x=df_final['Temperature (°C)'])
plt.show()

# %%
# Define a function to plot different types of time-series

def plot_series(df=None, column=None, series=pd.Series([]), 
                label=None, ylabel=None, title=None, start=0, end=None):
    """
    Plots a certain time-series which has either been loaded in a dataframe
    and which constitutes one of its columns or it a custom pandas series 
    created by the user. The user can define either the 'df' and the 'column' 
    or the 'series' and additionally, can also define the 'label', the 
    'ylabel', the 'title', the 'start' and the 'end' of the plot.
    """
    sns.set()
    fig, ax = plt.subplots(figsize=(30, 12))
    ax.set_xlabel('Time', fontsize=16)
    if column:
        ax.plot(df[column][start:end], label=label)
        ax.set_ylabel(ylabel, fontsize=16)
    if series.any():
        ax.plot(series, label=label)
        ax.set_ylabel(ylabel, fontsize=16)
    if label:
        ax.legend(fontsize=16)
    if title:
        ax.set_title(title, fontsize=24)
    ax.grid(True)
    return ax
    # Zoom into the plot of the hourly (actual) total load

# %%
# Plot the 'Temperature' for Bilbao
rolling2 = df_final['Temperature (°C)'].rolling(24*7, center=True).mean()

ax = plot_series(df_final, 'Temperature (°C)', 
                 label='Hourly', ylabel='Actual Temperature',
                 title='Temperature in Gyeongju-si')
ax.plot(rolling2, linestyle='-', linewidth=2, label='Weekly rolling mean')

plt.show()

# %% [markdown]
# ## <a id='ref14'>2.3. Autocorrelation, partial autocorrelation and cross-correlation</a>

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43807 entries, 2021-01-01 00:00:00 to 2019-12-31 23:00:00
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Temperature (°C)           43807 non-null  float64
#  1   °­¼ö·®(mm)                 43657 non-null  float64
#  2   Wind Speed ​​(m/s)         43807 non-null  float64
#  3   Ç³Çâ(16¹æÀ§)               43807 non-null  float64
#  4   Humidity (%)               43807 non-null  float64
#  5   Áõ±â¾Ð(hPa)                43807 non-null  float64
#  6   ÀÌ½½Á¡¿Âµµ(¡ÆC)            43807 non-null  float64
#  7   Barometric Pressure (hPa)  43807 non-null  float64
#  8   Sea Level Pressure (hPa)   43807 non-null  float64
#  9   Sunlight (hr)              43799 non-null  float64
#  10  Insolation (MJ/m^2)        43799 non-null  float64
#  11  Àû¼³(cm)                   42683 non-null  float64
#  12  3½Ã°£½ÅÀû¼³(cm)            0 non-null      float64
#  13  Àü¿î·®(10ºÐÀ§)             43807 non-null  float64
#  14  ÁßÇÏÃþ¿î·®(10ºÐÀ§)         43807 non-null  float64
#  15  ¿îÇü(¿îÇü¾à¾î)             0 non-null      float64
#  16  ÃÖÀú¿î°í(100m )            43797 non-null  float64
#  17  ½ÃÁ¤(10m)                  43807 non-null  float64
#  18  Áö¸é»óÅÂ(Áö¸é»óÅÂÄÚµå)     0 non-null      float64
#  19  Çö»ó¹øÈ£(±¹³»½Ä)           0 non-null      float64
#  20  Áö¸é¿Âµµ(¡ÆC)              43807 non-null  float64
#  21  5cm ÁöÁß¿Âµµ(¡ÆC)          43807 non-null  float64
#  22  10cm ÁöÁß¿Âµµ(¡ÆC)         43807 non-null  float64
#  23  20cm ÁöÁß¿Âµµ(¡ÆC)         43807 non-null  float64
#  24  30cm ÁöÁß¿Âµµ(¡ÆC)         43807 non-null  float64
# dtypes: float64(25)
# memory usage: 8.7 MB

# %% [markdown]
# ## <a id='ref17'>Feature selection</a>

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size
        
    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])
        
        if single_step:
            labels.append(target[i + target_size])
        else:
            labels.append(target[i : i + target_size])

    return np.array(data), np.array(labels)

# %%
train_end_idx = int(len(df_final)*0.70)
cv_end_idx = int(len(df_final)*0.85)
test_end_idx = len(df_final)

# %%
# Wind Direction (deg)            0.086512
# h_max                           0.035325
# Barometric Pressure (hPa)      -0.010425
# Sea Level Pressure (hPa)       -0.016479
# Precipitation (mm)             -0.092167
# Humidity (%)                   -0.548498
X = df_final['Temperature (°C)'].values
y = df_final['Temperature (°C)'].values
X = X.reshape(-1,1)
y = y.reshape(-1, 1)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# %%
X.shape
# Out:
# (43807, 1)

# %%
scaler_X.fit(X[:train_end_idx])
scaler_y.fit(y[:train_end_idx])
# Out:
# MinMaxScaler()

# %%
import joblib
scaler_filename = "scaler_temp.save"
joblib.dump(scaler_X, scaler_filename)
# Out:
# ['scaler_temp.save']

# %%
X_norm = scaler_X.transform(X)
y_norm = scaler_y.transform(y)

# %%
past_history = 24*7
future_target = 24

# %%
X_train, y_train = multivariate_data(X_norm, y_norm,
                                     0, train_end_idx, past_history, 
                                     future_target, step=1, single_step=False)

# %%
print(y_train.shape)
print(X_train.shape)
# Out:
# (30496, 24, 1)
# (30496, 168, 1)

# %%
X_val, y_val = multivariate_data(X_norm, y_norm,
                                 train_end_idx, cv_end_idx, past_history, 
                                 future_target, step=1, single_step=False)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# (6403, 168, 1)
# (6403, 24, 1)

# %%
X_test, y_test = multivariate_data(X_norm, y_norm,
                                   cv_end_idx, test_end_idx-past_history, past_history, 
                                   future_target, step=1, single_step=False)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (6236, 168, 1)
# (6236, 24, 1)

# %%
batch_size = 32
buffer_size = 1000

# %%
train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train = train.cache().shuffle(buffer_size).batch(batch_size).prefetch(1)

validation = tf.data.Dataset.from_tensor_slices((X_val, y_val))
validation = validation.batch(batch_size).prefetch(1)

# %%
# Define some common parameters

input_shape = X_train.shape[-2:]
loss = tf.keras.losses.MeanSquaredError()
metric = [tf.keras.metrics.RootMeanSquaredError()]
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
              lambda epoch: 1e-4 * 10**(epoch / 10))
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10)

# %%
y_test.shape
# Out:
# (6236, 24, 1)

# %%
#y_test = y_test.reshape(-1, 1)
y_test = y_test.reshape(-1, future_target)
y_test_inv = scaler_y.inverse_transform(y_test)

# %%
def plot_model_rmse_and_loss(history):
    
    # Evaluate train and validation accuracies and losses
    
    train_rmse = history.history['root_mean_squared_error']
    val_rmse = history.history['val_root_mean_squared_error']
    
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    # Visualize epochs vs. train and validation accuracies and losses
    
    plt.figure(figsize=(20, 10))
    plt.subplot(1, 2, 1)
    plt.plot(train_rmse, label='Training RMSE')
    plt.plot(val_rmse, label='Validation RMSE')
    plt.legend()
    plt.title('Epochs vs. Training and Validation RMSE')
    
    plt.subplot(1, 2, 2)
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend()
    plt.title('Epochs vs. Training and Validation Loss')
    
    plt.show()

# %% [markdown]
# ## Stacked LSTM

# %%
tf.keras.backend.clear_session()
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, TimeDistributed, Flatten, Dropout, RepeatVector

multivariate_stacked_lstm = tf.keras.models.Sequential([
    LSTM(250, input_shape=input_shape, 
         return_sequences=True),
    LSTM(150, return_sequences=True),
    Flatten(),
    Dense(150, activation='relu'),
    Dropout(0.1),
    Dense(future_target)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'temperature_stacked_lstm.h5', save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=3e-3, amsgrad=True)

multivariate_stacked_lstm.compile(loss=loss,
                                  optimizer=optimizer,
                                  metrics=metric)

# %%
history = multivariate_stacked_lstm.fit(train, epochs=120,
                                validation_data=validation,
                                callbacks=[early_stopping, 
                                           model_checkpoint])
# Out:
# Epoch 1/120
# 953/953 [==============================] - 684s 711ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 2/120
# 953/953 [==============================] - 682s 716ms/step - loss: 0.0057 - root_mean_squared_error: 0.0756 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0649
# Epoch 3/120
# 953/953 [==============================] - 635s 666ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0631
# Epoch 4/120
# 953/953 [==============================] - 637s 669ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0599
# Epoch 5/120
# 953/953 [==============================] - 642s 674ms/step - loss: 0.0041 - root_mean_squared_error: 0.0641 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0593
# Epoch 6/120
# 953/953 [==============================] - 624s 655ms/step - loss: 0.0039 - root_mean_squared_error: 0.0627 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0598
# Epoch 7/120
# 953/953 [==============================] - 631s 662ms/step - loss: 0.0038 - root_mean_squared_error: 0.0619 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0570
# Epoch 8/120
# 953/953 [==============================] - 634s 666ms/step - loss: 0.0037 - root_mean_squared_error: 0.0612 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0556
# Epoch 9/120
# 953/953 [==============================] - 635s 666ms/step - loss: 0.0037 - root_mean_squared_error: 0.0606 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0555
# Epoch 10/120
# 953/953 [==============================] - 649s 681ms/step - loss: 0.0036 - root_mean_squared_error: 0.0599 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0564
# Epoch 11/120
# 953/953 [==============================] - 685s 719ms/step - loss: 0.0036 - root_mean_squared_error: 0.0597 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 12/120
# 953/953 [==============================] - 688s 722ms/step - loss: 0.0035 - root_mean_squared_error: 0.0593 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0570
# Epoch 13/120
# 953/953 [==============================] - 668s 701ms/step - loss: 0.0034 - root_mean_squared_error: 0.0586 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0552
# Epoch 14/120
# 953/953 [==============================] - 622s 653ms/step - loss: 0.0034 - root_mean_squared_error: 0.0585 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0545
# Epoch 15/120
# 953/953 [==============================] - 698s 732ms/step - loss: 0.0034 - root_mean_squared_error: 0.0583 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0558
# Epoch 16/120
# 953/953 [==============================] - 885s 929ms/step - loss: 0.0033 - root_mean_squared_error: 0.0577 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0572
# Epoch 17/120
# 953/953 [==============================] - 835s 876ms/step - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 18/120
# 953/953 [==============================] - 760s 798ms/step - loss: 0.0033 - root_mean_squared_error: 0.0571 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0579
# Epoch 19/120
# 953/953 [==============================] - 755s 793ms/step - loss: 0.0033 - root_mean_squared_error: 0.0570 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0562
# Epoch 20/120
# 953/953 [==============================] - 756s 794ms/step - loss: 0.0032 - root_mean_squared_error: 0.0564 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 21/120
# 953/953 [==============================] - 751s 788ms/step - loss: 0.0032 - root_mean_squared_error: 0.0562 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
# Epoch 22/120
# 953/953 [==============================] - 759s 796ms/step - loss: 0.0031 - root_mean_squared_error: 0.0558 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 23/120
# 953/953 [==============================] - 760s 798ms/step - loss: 0.0031 - root_mean_squared_error: 0.0556 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# Epoch 24/120
# 953/953 [==============================] - 739s 775ms/step - loss: 0.0030 - root_mean_squared_error: 0.0552 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568

# %%
plot_model_rmse_and_loss(history)

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_percentage_error
multivariate_stacked_lstm = tf.keras.models.load_model('temperature_stacked_lstm.h5')

forecast = multivariate_stacked_lstm.predict(X_test)
multivariate_stacked_lstm_forecast = scaler_y.inverse_transform(forecast)
# Out:
# 195/195 [==============================] - 53s 270ms/step
# RMSE of 24 hour-ahead temperature Stacked LSTM forecast: 2.647
# R2 score of 24 hour-ahead temperature Stacked LSTM forecast: 2.647

# %%
rmse_mult_stacked_lstm = sqrt(mean_squared_error(y_test_inv, 
                                                 multivariate_stacked_lstm_forecast))
print('RMSE of 24 hour-ahead temperature Stacked LSTM forecast: {}'
      .format(round(rmse_mult_stacked_lstm, 3)))

r2_mult_stacked_lstm = r2_score(y_test_inv,multivariate_stacked_lstm_forecast)
print('R2 score of 24 hour-ahead temperature Stacked LSTM forecast: {}%'
      .format(round(r2_mult_stacked_lstm*100, 3)))

mape_mult_stacked_lstm = scaler_y.inverse_transform(mean_absolute_percentage_error(y_test,forecast).reshape(-1,1))
print('MAPE of 24 hour-ahead temperature Stacked LSTM forecast: {}%'
      .format(round(abs(mape_mult_stacked_lstm[0][0]), 3)))
# Out:
# RMSE of 24 hour-ahead temperature Stacked LSTM forecast: 2.647
# R2 score of 24 hour-ahead temperature Stacked LSTM forecast: 89.973%
# MAPE of 24 hour-ahead temperature Stacked LSTM forecast: 9.069%

# %%
y_test_inv[0]
# Out:
# array([ 1.9,  1.3,  2. ,  2.9,  5.5,  9.5, 13.5, 14.7, 15.2, 15. , 13.5,
#        12.3, 11.1,  9.8,  9.5,  8.9,  8.1,  6.8,  6.3,  6. ,  6.1,  6.5,
#         7.1,  6.8])

# %%
multivariate_stacked_lstm_forecast[0]
# Out:
# array([ 3.139215 ,  2.5942185,  3.0118744,  4.778548 ,  7.90587  ,
#        11.242253 , 13.487848 , 15.336283 , 16.888433 , 18.738708 ,
#        17.798626 , 17.52216  , 17.21191  , 15.785049 , 14.598206 ,
#        13.204041 , 11.727753 , 10.376661 , 10.541616 ,  8.923131 ,
#         8.8211975,  8.077635 ,  7.0327578,  6.6674833], dtype=float32)

# %%
plt.plot(y_test_inv[:100,0],'b-')
plt.plot(multivariate_stacked_lstm_forecast[:100,0],'g-')
